# %% [markdown]
# <a href="https://colab.research.google.com/github/MtBalbine/PROJETO-1---ESTATISTICA-E-ANALISE-DE-DADOS/blob/main/VarQualiPorte.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 1. Importar as bibliotecas Pandas (pd) e math

# %%
import pandas as pd
import math
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# 2. Definir a variável "arquivo" pelo nome da planilha.

# %%
arquivo='economia_circular.xlsx'

# %% [markdown]
# 3. Ler a planilha no Python. Escolha um nome para armazenar. Escolheremos df

# %%
df=pd.read_excel(arquivo)
df
# Out:
#            Setor    Porte  Taxa_Circularidade_percent  Indice_Sustentabilidade
# 0         Têxtil  Pequeno                        10.5                     24.3
# 1         Têxtil    Médio                        14.0                     27.0
# 2      Alimentos  Pequeno                        21.2                     27.2
# 3      Alimentos    Médio                        16.0                     28.1
# 4    Eletrônicos  Pequeno                        19.9                     28.9
# ..           ...      ...                         ...                      ...
# 273   Metalurgia   Grande                       100.0                     86.9
# 274   Metalurgia   Grande                       100.0                     87.7
# 275   Metalurgia   Grande                       100.0                     88.3
# 276    Plásticos   Grande                       100.0                     88.8
# 277   Metalurgia   Grande                       100.0                     94.2
#
# [278 rows x 4 columns]

# %% [markdown]
# 4.Agrupando os valores qualitativos a partir da variável selecionada.Escolhemos Escolaridade (nome da coluna no arquivo df). **Os valores serão armamzenados em df2.**

# %%
df2=df.Porte.value_counts()
df2
# Out:
# Porte
# Médio      119
# Pequeno     80
# Grande      79
# Name: count, dtype: int64

# %% [markdown]
# 5. Ordenando os valores da variável em ordem alfabética

# %%
df2=df.Porte.value_counts().sort_index()
df2
# Out:
# Porte
# Grande      79
# Médio      119
# Pequeno     80
# Name: count, dtype: int64

# %% [markdown]
# 6. Contando o total de elementos

# %%
totaldf2=df2.sum()
totaldf2
# Out:
# np.int64(278)

# %% [markdown]
# 7. Montando a tabela de frequências da variável

# %% [markdown]
# 7.1. Criar um DataFrame para a coluna desejada (dadosvquali no exemplo)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
dadosvquali=pd.DataFrame(df2)

# %%
dadosvquali
# Out:
#          count
# Porte
# Grande      79
# Médio      119
# Pequeno     80

# %%
# Cria um DataFrame a partir da Série df2
dadosvquali = pd.DataFrame(df2).reset_index()

# Renomeia as colunas para algo mais descritivo
dadosvquali.columns = ['Porte', 'Quantidade de Empresas']

# Exibe o DataFrame
print(dadosvquali)
# Out:
#      Porte  Quantidade de Empresas
# 0   Grande                      79
# 1    Médio                     119
# 2  Pequeno                      80

# %% [markdown]
# 7.2 Calcular a frequencia relativa em % com 2 casas decimais

# %%
# Calcula a porcentagem de frequência de cada categoria
dadosvquali['Frequência Relativa (%)'] = round(dadosvquali['Quantidade de Empresas'] * 100 / totaldf2, 2)

# Exibe o DataFrame atualizado
print(dadosvquali)
# Out:
#      Porte  Quantidade de Empresas  Frequência Relativa (%)
# 0   Grande                      79                    28.42
# 1    Médio                     119                    42.81
# 2  Pequeno                      80                    28.78

# %% [markdown]
# 7.3 Criando uma nova tabela, renomeando as colunas

# %%
tabela=pd.DataFrame({"Porte":dadosvquali['Porte'],"Quantidade de Empresas":dadosvquali['Quantidade de Empresas'],"Frequência Relativa (%)":dadosvquali["Frequência Relativa (%)"]})

# %%
tabela
# Out:
#      Porte  Quantidade de Empresas  Frequência Relativa (%)
# 0   Grande                      79                    28.42
# 1    Médio                     119                    42.81
# 2  Pequeno                      80                    28.78

# %%
rótulos1 = tabela['Porte']
valores1 = tabela['Quantidade de Empresas']
plt.figure(figsize=(7,7))
plt.pie(valores1,labels=rótulos1,autopct='%1.1f%%',startangle=90)
plt.legend()
plt.title('Distribuição de Empresas por Porte') # Adiciona o título aqui
plt.show()
